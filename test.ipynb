# %%
import requests
hey = requests.get("https://telugu.krishijagran.com/")
hey
# Out:
# <Response [200]>

# %%
hey.content
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html xmlns="http://www.w3.org/1999/xhtml" lang="te">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0" />\r\n    <meta name="robots" content="index, follow" />\r\n    <meta property="fb:pages" content="1435740416658252" />\r\n    <meta property="fb:app_id" content="223470428180832" />\r\n    <meta property="og:title" content="Agriculture News in Telugu, news from Telengana, Andhra Pradesh." />\r\n    <meta name="description">\r\n    <meta property="og:type" />\r\n    <meta property="og:description" />\r\n    <meta property="og:image" />\r\n    <meta property="og:url" content="https://telugu.krishijagran.com/" />\r\n    <meta name="twitter:card" content="summary_large_image">\r\n    <meta name="twitter:site" content="@krishijagran">\r\n    <meta name="twitter:creator" content="Krishi Jagran">\r\n    <meta name="t
# ...
